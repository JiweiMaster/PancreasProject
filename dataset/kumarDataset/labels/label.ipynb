# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
labelSameDataSet = np.load('labelSameDataSet.npy')
print(labelSameDataSet.shape)

plt.imshow(labelSameDataSet[6])
# Out:
# (8, 1000, 1000)
